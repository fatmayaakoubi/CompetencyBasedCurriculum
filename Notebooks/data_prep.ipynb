# %%
# !pip install argostranslate

# %%
import pandas as pd
import re
import argostranslate.package
import argostranslate.translate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load data into a Data Frame

# %%
data = pd.read_csv('/content/drive/MyDrive/Datasets/Scraped/NIDS.csv')

# %% [markdown]
# ### Data Visualization

# %%
data.shape
# Out:
# (140, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             140 non-null    object
#  1   Education        71 non-null     object
#  2   Experiences      91 non-null     object
#  3   Graduation_Year  140 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 4.5+ KB

# %%
data.head()
# Out:
#                  Name                                          Education  \
# 0      Paul Yoan KOME  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 1   Marwen Ben Mihoub  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 2         Florin Kiss                                                NaN
# 3        Mehdi JAAFAR                                                NaN
# 4  Ayoub Belhadjyahia  Ecole Supérieure Privée d'Ingénierie et de Tec...
#
#                                          Experiences  Graduation_Year
# 0  Within the executive B2B division, SFR needs i...             1973
# 1  Currently part of the Attack and Penetration T...             2017
# 2  .lumen builds glasses that empower the blind t...                0
# 3  -Conception and full stack implementation of a...                0
# 4                                                NaN             2024

# %%
data.isnull().sum()
# Out:
# Name                0
# Education          69
# Experiences        49
# Graduation_Year     0
# dtype: int64

# %%
data['Name'].value_counts()
# Out:
# Paul Yoan KOME          1
# Jérémie L.              1
# Nesrine Talbi           1
# Siwar Dahmani           1
# Mohamed Aymen Ourabi    1
#                        ..
# sara ibrahim            1
# HNIA M'hamed            1
# Ahmed Belkahla          1
# Oussama FILALI          1
# Dr Magda Chelly         1
# Name: Name, Length: 140, dtype: int64

# %%
data.nunique()
# Out:
# Name               140
# Education           71
# Experiences         91
# Graduation_Year     18
# dtype: int64

# %%
data = data.astype(str)

# %% [markdown]
# # Data Cleaning ###

# %% [markdown]
# #### Remove duplicate profiles

# %%
data = data.drop_duplicates(subset=['Name'])

# %%
data.shape
# Out:
# (140, 4)

# %%
data.head(10)
# Out:
#                       Name                                          Education  \
# 0           Paul Yoan KOME  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 1        Marwen Ben Mihoub  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 2              Florin Kiss                                                nan
# 3             Mehdi JAAFAR                                                nan
# 4       Ayoub Belhadjyahia  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 5          Yasmine Karaoui  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 6              Yosr GHOZZI                                                nan
# 7  Christopher (Kit) Henry                                                nan
# 8               Arij M'tar  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 9              raed bahria  Ecole Supérieure Privée d'Ingénierie et de Tec...
#
#                                          Experiences Graduation_Year
# 0  Within the executive B2B division, SFR needs i...            1973
# 1  Currently part of the Attack and Penetration T...            2017
# 2  .lumen builds glasses that empower the blind t...               0
# 3  -Conception and full stack implementation of a...               0
# 4                                                nan            2024
# 5  During my summer internship, I had the opportu...            2024
# 6  Skills: Automatic Learning · Improvement of bu...               0
# 7  Cyber Security Program Manager / System Engine...               0
# 8  BUSINESS INTELLIGENCE Project: Development of ...            2020
# 9                                                nan            2024

# %% [markdown]
# #### Remove text leading and trailing whitespaces

# %%
data['Experiences'] = data['Experiences'].str.strip()

# %%
data['Education'] = data['Education'].str.strip()

# %% [markdown]
# #### Remove empty experiences

# %%
data = data[~data['Experiences'].isin(['', 'nan', 'No Result'])]

# %%
data.shape
# Out:
# (91, 4)

# %%
data
# Out:
#                   Name                                          Education  \
# 0       Paul Yoan KOME  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 1    Marwen Ben Mihoub  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 2          Florin Kiss                                                nan
# 3         Mehdi JAAFAR                                                nan
# 5      Yasmine Karaoui  Ecole Supérieure Privée d'Ingénierie et de Tec...
# ..                 ...                                                ...
# 132        Omar YAZIDI  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 134   BALLESTEROS Hugo                                                nan
# 135     Richard Dufour                                                nan
# 138  Roman Vitkovitsky                                                nan
# 139    Dr Magda Chelly                                                nan
#
#                                            Experiences Graduation_Year
# 0    Within the executive B2B division, SFR needs i...            1973
# 1    Currently part of the Attack and Penetration T...            2017
# 2    .lumen builds glasses that empower the blind t...               0
# 3    -Conception and full stack implementation of a...               0
# 5    During my summer internship, I had the opportu...            2024
# ..                                                 ...             ...
# 132  Design, Implementation and Evaluation of an An...            2017
# 134  Governance:\n- Development of security policie...               0
# 135  Skills: DNS · Nmap · AngularJS · Python (progr...               0
# 138  Dedicated Plankholder and Servant Leader Opera...               0
# 139  I am a Global Citizen, Tunisian and Polish by ...               0
#
# [91 rows x 4 columns]

# %% [markdown]
# #### Translation of Experiences to English

# %%
from_code = "fr"
to_code = "en"

# Download and install Argos Translate package
argostranslate.package.update_package_index()
available_packages = argostranslate.package.get_available_packages()
package_to_install = next(
    filter(
        lambda x: x.from_code == from_code and x.to_code == to_code, available_packages
    )
)
argostranslate.package.install_from_path(package_to_install.download()) # type: ignore

# Define a function to translate a text from French to English
def translate_fr_to_en(text):
    if isinstance(text, str):
        translatedText = argostranslate.translate.translate(text, from_code, to_code)
        return translatedText
    else:
        return text

# %%
# Apply the translation function to the Experiences column
data['Experiences'] = data['Experiences'].apply(translate_fr_to_en)

# %%
data.head(10)
# Out:
#                        Name  \
# 0            Paul Yoan KOME
# 1         Marwen Ben Mihoub
# 2               Florin Kiss
# 3              Mehdi JAAFAR
# 5           Yasmine Karaoui
# 6               Yosr GHOZZI
# 7   Christopher (Kit) Henry
# 8                Arij M'tar
# 10               Saif Faleh
# 15             Talel CHELBI
#
#                                             Education  \
# 0   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 1   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 2                                                 nan
# 3                                                 nan
# 5   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 6                                                 nan
# 7                                                 nan
# 8   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 10  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 15  Ecole Supérieure Privée d'Ingénierie et de Tec...
#
#                                           Experiences Graduation_Year
# 0   Within the executive B2B division, SFR needs i...            1973
# 1   Currently part of the Attack and Penetration T...            2017
# 2   .lumen builds glasses that empower the blind t...               0
# 3   -Conception and full stack implementation of a...               0
# 5   During my summer internship, I had the opportu...            2024
# 6   Skills: Automatic Learning · Improvement of bu...               0
# 7   Cyber Security Program Manager / System Engine...               0
# 8   BUSINESS INTELLIGENCE Project: Development of ...            2020
# 10  Design and Development of an application for D...            2014
# 15  Cyber security compliance\nCyber security asse...            2017

# %% [markdown]
# #### Extraction of graduation year from ESPRIT

# %%
# Regular expression pattern to match a four-digit year
year_pattern = r"\b\d{4}\b"

# Function to extract graduation year
def extract_grad_year(education_str):
    match = re.findall(year_pattern, education_str)
    return pd.Series(match[-1] if match else 0)

# Apply the extract_grad_year function to the 'Education' column to create a new 'Graduation_Year' column
data['Graduation_Year'] = data['Education'].apply(extract_grad_year)

# %%
data.head(10)
# Out:
#                        Name  \
# 0            Paul Yoan KOME
# 1         Marwen Ben Mihoub
# 2               Florin Kiss
# 3              Mehdi JAAFAR
# 5           Yasmine Karaoui
# 6               Yosr GHOZZI
# 7   Christopher (Kit) Henry
# 8                Arij M'tar
# 10               Saif Faleh
# 15             Talel CHELBI
#
#                                             Education  \
# 0   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 1   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 2                                                 nan
# 3                                                 nan
# 5   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 6                                                 nan
# 7                                                 nan
# 8   Ecole Supérieure Privée d'Ingénierie et de Tec...
# 10  Ecole Supérieure Privée d'Ingénierie et de Tec...
# 15  Ecole Supérieure Privée d'Ingénierie et de Tec...
#
#                                           Experiences Graduation_Year
# 0   Within the executive B2B division, SFR needs i...            1973
# 1   Currently part of the Attack and Penetration T...            2017
# 2   .lumen builds glasses that empower the blind t...               0
# 3   -Conception and full stack implementation of a...               0
# 5   During my summer internship, I had the opportu...            2024
# 6   Skills: Automatic Learning · Improvement of bu...               0
# 7   Cyber Security Program Manager / System Engine...               0
# 8   BUSINESS INTELLIGENCE Project: Development of ...            2020
# 10  Design and Development of an application for D...            2014
# 15  Cyber security compliance\nCyber security asse...            2017

# %%
data[data['Education']=='nan'].count()
# Out:
# Name               48
# Education          48
# Experiences        48
# Graduation_Year    48
# dtype: int64

# %%
data.Graduation_Year.value_counts()
# Out:
# 0       49
# 2020     7
# 2019     6
# 2017     5
# 2022     4
# 2023     4
# 2014     3
# 2018     3
# 2024     2
# 2025     2
# 1973     1
# 2016     1
# 2008     1
# 2021     1
# 2013     1
# 2010     1
# Name: Graduation_Year, dtype: int64

# %%
data.shape
# Out:
# (91, 4)

# %% [markdown]
# #### Export results to CSV

# %%
data.to_csv('/content/drive/MyDrive/Datasets/Clean/NIDS.csv', index=False)
